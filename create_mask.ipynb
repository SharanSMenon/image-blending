# %%
import cv2
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from utils import get_mask, specify_mask, specify_bottom_center, align_source
import os

# %%
# Feel free to change image
background_img = cv2.cvtColor(cv2.imread('images/beach.jpg'), cv2.COLOR_BGR2RGB).astype('double') / 255.0 
plt.figure()
plt.imshow(background_img)

# %%
object_img = cv2.cvtColor(cv2.imread('images/stormtrooper-sm.jpg'), cv2.COLOR_BGR2RGB).astype('double') / 255.0 
import matplotlib.pyplot as plt
# %matplotlib notebook
mask_coords = specify_mask(object_img)
# Out:
# If it doesn't get you to the drawing mode, then rerun this function again.
# <img src="data:image/png;base64,..." width="432">

# %%
xs = mask_coords[0]
ys = mask_coords[1]
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure()
mask = get_mask(ys, xs, object_img)

# %%
cv2.imwrite("stormtrooper_mask.png", mask*255)
# Out:
# True

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
bottom_center = specify_bottom_center(background_img)
# Out:
# If it doesn't get you to the drawing mode, then rerun this function again. Also, make sure the object fill fit into the background image. Otherwise it will crash
# <img src="data:image/png;base64,..." width="432">

# %%
bottom_center = [1659, 1796]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
cropped_object, object_mask = align_source(object_img, mask, background_img, bottom_center)
